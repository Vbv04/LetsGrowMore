# %% [markdown]
# # Task 4-  Image to pencil sketch with python
#
# ### Name- Vaibhavi Sujit Dhumal

# %% [markdown]
# ### 1) Importing the library

# %%
import cv2

# %% [markdown]
# ### 2) Loading the image

# %%
img_loc = r"C:\Users\Admin\Downloads"
img1 = "lake.jpg"

# %%
img = cv2.imread(r"C:\Users\Admin\Downloads\lake.jpg")

# %%
# Original image

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %% [markdown]
# ### 3) Converting into Gray scale

# %%
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image)

# %% [markdown]
# ### 4) Inverting the grayscale image/ negative image

# %%
inverted_image = cv2.bitwise_not(gray_image)
plt.imshow(inverted_image)

# %% [markdown]
# ### 5) Soothing the image

# %%
img_smoothing = cv2.GaussianBlur(inverted_image, (21, 21),sigmaX=0, sigmaY=0)
plt.imshow(img_smoothing)

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256.0)

# %% [markdown]
# ### 6) Inverting the image to get the pencil sketch

# %%
pencil_sketch = dodgeV2(gray_image, img_smoothing)
plt.imshow(pencil_sketch)

# %% [markdown]
# ### 7) Comparing the original image with the pencil sketch

# %%
display(Image.fromarray(img_rgb))
display(Image.fromarray(pencil_sketch))
# Out:
# <PIL.Image.Image image mode=RGB size=295x225 at 0x260F438E910>
# <PIL.Image.Image image mode=L size=295x225 at 0x260F43822E0>
